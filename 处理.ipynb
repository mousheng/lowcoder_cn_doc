# %%
import os
import re


# 定义一个函数来处理每个文件
def process_md_file(file_path):
    with open(file_path, "r", encoding="utf-8") as file:
        content = file.read()
    # 使用正则表达式删除以---开始和以---结束的文本
    content = re.sub(r"\n^---.*?---\n", "", content, flags=re.MULTILINE | re.DOTALL)
    lines = content.split("\n")
    title = lines[0][2:]
    title2 = lines[1].strip() if lines[1].strip() != "" else lines[2].strip()
    index = 1 if lines[1].strip() != "" else 2
    if lines[0].startswith("# ") and title == title2:
        lines.pop(index)

    # 保存修改后的内容回到文件中
    with open(file_path, "w", encoding="utf-8") as file:
        file.write("\n".join(lines).replace("\n\n\n", "\n\n"))

# 处理文件引用
def process_md_image(file_path, deep):
    with open(file_path, "r", encoding="utf-8") as file:
        content = file.read()
    path = '../' * deep
    content = content.replace('''​![](assets/''', f"![]({path}assets/")

    # 保存修改后的内容回到文件中
    with open(file_path, "w", encoding="utf-8") as file:
        file.write(content)

# 遍历文件夹下的所有.md文件
folder_path = "/home/mou/locoder_cn_doc/"  # 将此路径替换为你的文件夹路径
for root, dirs, files in os.walk(folder_path):
    for file in files:
        if file.endswith(".md"):
            subPath = root.replace(folder_path, "")
            if subPath == "":
                deep = 0
            else:
                deep = len(subPath.split("/"))
            file_path = os.path.join(root, file)
            process_md_file(file_path)
            # process_md_image(file_path, deep)
            print(f"处理文件: {file_path}")

print("完成处理所有.md文件")
# Out:
# 处理文件: /home/mou/locoder_cn_doc/数据安全.md
# 处理文件: /home/mou/locoder_cn_doc/更新日志.md
# 处理文件: /home/mou/locoder_cn_doc/新手上路.md
# 处理文件: /home/mou/locoder_cn_doc/Lowcoder是什么.md
# 处理文件: /home/mou/locoder_cn_doc/常见问题 (FAQ).md
# 处理文件: /home/mou/locoder_cn_doc/私有化部署/如何访问宿主机 APIDB.md
# 处理文件: /home/mou/locoder_cn_doc/私有化部署/Docker.md
# 处理文件: /home/mou/locoder_cn_doc/开发应用/模块 (Module).md
# 处理文件: /home/mou/locoder_cn_doc/开发应用/使用第三方库.md
# 处理文件: /home/mou/locoder_cn_doc/开发应用/应用发布与历史记录.md
# 处理文件: /home/mou/locoder_cn_doc/开发应用/创建应用.md
# 处理文件: /home/mou/locoder_cn_doc/开发应用/快捷键.md
# 处理文件: /home/mou/locoder_cn_doc/开发应用/事件 (Event).md
# 处理文件: /home/mou/locoder_cn_doc/开发应用/应用编辑界面.md
# 处理文件: /home/mou/locoder_cn_doc/开发应用/聚合页.md
# 处理文件: /home/mou/locoder_cn_doc/开发应用/样式、主题与友好交互/README.md
# 处理文件: /home/mou/locoder_cn_doc/开发应用/样式、主题与友好交互/表单设计技巧.md
# 处理文件: /home/mou/locoder_cn_doc/开发应用/样式、主题与友好交互/自定义 CSS 注意事项.md
# 处理文件: /home/mou/locoder_cn_doc/开发应用/样式、主题与友好交互/自定义 CSS 使用样例.md
# 处理文件: /home/mou/locoder_cn_doc/开发应用/组件指南/README.md
# 处理文件: /home/mou/locoder_cn_doc/开发应用/组件指南/charts-and-graphs.md
# 处理文件: /home/mou/locoder_cn_doc/开发应用/组件指南/use-markdown.md
# 处理文件: /home/mou/locoder_cn_doc/开发应用/组件指南/custom-component.md
# 处理文件: /home/mou/locoder_cn_doc/开发应用/组件指南/list-view.md
# 处理文件: /home/mou/locoder_cn_doc/开发应用/组件指南/option-lists.md
# 处理文件: /home/mou/locoder_cn_doc/开发应用/组件指南/drawer.md
# 处理文件: /home/mou/locoder_cn_doc/开发应用/组件指南/image.md
# 处理文件: /home/mou/locoder_cn_doc/开发应用/组件指南/file-upload.md
# 处理文件: /home/mou/locoder_cn_doc/开发应用/使用JavaScript/README.md
# 处理文件: /home/mou/locoder_cn_doc/开发应用/使用JavaScript/JavaScript 表达式.md
# 处理文件: /home/mou/locoder_cn_doc/开发应用/使用JavaScript/操作数组.md
# 处理文件: /home/mou/locoder_cn_doc/开发应用/使用JavaScript/转换器.md
# 处理文件: /home/mou/locoder_cn_doc/开发应用/使用JavaScript/临时状态.md
# 处理文件: /home/mou/locoder_cn_doc/开发应用/使用JavaScript/操作日期与时间.md
# 处理文件: /home/mou/locoder_cn_doc/开发应用/使用JavaScript/JavaScript 查询.md
# 处理文件: /home/mou/locoder_cn_doc/开发应用/使用JavaScript/使用系统函数.md
# 处理文件: /home/mou/locoder_cn_doc/开发应用/使用JavaScript/使用第三方库.md
# 处理文件: /home/mou/locoder_cn_doc/开发应用/使用JavaScript/数据变化响应器.md
# 处理文件: /home/mou/locoder_cn_doc/数据源/IP 白名单.md
# 处理文件: /home/mou/locoder_cn_doc/数据源/管理数据源.md
# 处理文件: /home/mou/locoder_cn_doc/数据源/连接到API/README.md
# 处理文件: /home/mou/locoder_cn_doc/数据源/连接到API/连接 GraphQL.md
# 处理文件: /home/mou/locoder_cn_doc/数据源/连接到API/连接 REST API.md
# 处理文件: /home/mou/locoder_cn_doc/数据源/连接到数据库/README.md
# 处理文件: /home/mou/locoder_cn_doc/数据源/连接到数据库/连接 MySQL.md
# 处理文件: /home/mou/locoder_cn_doc/数据源/连接到数据库/连接 OceanBase.md
# 处理文件: /home/mou/locoder_cn_doc/数据源/连接到数据库/连接 DynamoDB.md
# 处理文件: /home/mou/locoder_cn_doc/数据源/连接到数据库/连接达梦 DM.md
# 处理文件: /home/mou/locoder_cn_doc/数据源/连接到数据库/连接 MariaDB.md
# 处理文件: /home/mou/locoder_cn_doc/数据源/连接到数据库/连接 StarRocks.md
# 处理文件: /home/mou/locoder_cn_doc/数据源/连接到数据库/连接 MongoDB.md
# 处理文件: /home/mou/locoder_cn_doc/数据源/连接到数据库/连接 MogDB.md
# 处理文件: /home/mou/locoder_cn_doc/数据源/连接到数据库/连接 TiDB.md
# 处理文件: /home/mou/locoder_cn_doc/数据源/连接到数据库/连接 openGauss.md
# 处理文件: /home/mou/locoder_cn_doc/数据源/连接到数据库/连接 Elasticsearch.md
# 处理文件: /home/mou/locoder_cn_doc/数据源/连接到数据库/连接 GaussDB.md
# 处理文件: /home/mou/locoder_cn_doc/数据源/连接到数据库/连接 Microsoft SQL server.md
# 处理文件: /home/mou/locoder_cn_doc/数据源/连接到数据库/连接 PolarDB.md
# 处理文件: /home/mou/locoder_cn_doc/数据源/连接到数据库/连接 SequoiaDB.md
# 处理文件: /home/mou/locoder_cn_doc/数据源/连接到数据库/连接 CouchDB.md
# 处理文件: /home/mou/locoder_cn_doc/数据源/连接到数据库/连接 TDengine.md
# 处理文件: /home/mou/locoder_cn_doc/数据源/连接到数据库/连接 Redis.md
# 处理文件: /home/mou/locoder_cn_doc/数据源/连接到数据库/连接 Oracle.md
# 处理文件: /home/mou/locoder_cn_doc/数据源/连接到数据库/连接 ClickHouse.md
# 处理文件: /home/mou/locoder_cn_doc/数据源/连接到数据库/连接 PostgreSQL.md
# 处理文件: /home/mou/locoder_cn_doc/查询/使用 SQL.md
# 处理文件: /home/mou/locoder_cn_doc/查询/查询 (Query).md
# 处理文件: /home/mou/locoder_cn_doc/查询/查询库.md
# 处理文件: /home/mou/locoder_cn_doc/查询/使用 REST API.md
# 完成处理所有.md文件
